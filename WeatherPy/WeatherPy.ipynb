# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

from citipy import citipy

#CSV
output_data_file = "./cities.csv"

# Range of lat/lngs
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat/lngs and cities
lat_lngs = []
cities = []

# Random lat/lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Nearest city for each combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %%
n=0
weather_data = []
for city in cities:
    n=n+1
    print(city)
    url = (f"https://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}")
    response = requests.get(url).json()
    try:
        weather_data.append(
            {
                'City': city,
                'Lat': response['coord']['lat'],
                'Lng': response['coord']['lon'],
                'Max Temp': response['main']['temp_max'],
                'Humidity': response['main']['humidity'],
                'Cloudiness': response['clouds']['all'],
                'Wind Speed': response['wind']['speed'],
                'Country': response['sys']['country'],
                'Date': datetime.datetime.fromtimestamp(int(response['dt'])).strftime('%Y-%m-%d %H:%M')
            }
        )
    except:
        next
    print(f"Processing Record {n} of {len(cities)} | {city}")

weather_df = pd.DataFrame(weather_data)
# Out:
# ushuaia
# Processing Record 1 of 630 | ushuaia
# lima
# Processing Record 2 of 630 | lima
# rikitea
# Processing Record 3 of 630 | rikitea
# college
# Processing Record 4 of 630 | college
# bluff
# Processing Record 5 of 630 | bluff
# richards bay
# Processing Record 6 of 630 | richards bay
# cabo san lucas
# Processing Record 7 of 630 | cabo san lucas
# labuhan
# Processing Record 8 of 630 | labuhan
# aflu
# Processing Record 9 of 630 | aflu
# nikolskoye
# Processing Record 10 of 630 | nikolskoye
# qaanaaq
# Processing Record 11 of 630 | qaanaaq
# rungata
# Processing Record 12 of 630 | rungata
# barrow
# Processing Record 13 of 630 | barrow
# stamsund
# Processing Record 14 of 630 | stamsund
# cascais
# Processing Record 15 of 630 | cascais
# kamenskoye
# Processing Record 16 of 630 | kamenskoye
# ilulissat
# Processing Record 17 of 630 | ilulissat
# noumea
# Processing Record 18 of 630 | noumea
# ribeira grande
# Processing Record 19 of 630 | ribeira grande
# kaukauna
# Processing Record 20 of 630 | kaukauna
# funtua
# Processing Record 21 of 630 | funtua
# hilo
# Processing Record 22 of 630 | hilo
# yellowknife
# Processing Record 23 of 630 | yellowknife
# kavieng
# Processing Record 24 of 630 | kavieng
# cap malheureux
# Processing Record 25 of 630 | cap malheureux
# albany
# Processing Record 26 of 630 | albany
# punta arenas
# Processing Record 27 of 630 | punta arenas
# tabuk
# Processing Record 28 of 630 | tabuk
# nanakuli
# Processing Record 29 of 630 | nanakuli
# murgab
# Processing Record 30 of 630 | murgab
# mys shmidta
# Processing Record 31 of 630 | mys shmidta
# kapit
# Processing Record 32 of 630 | kapit
# vaini
# Processing Record 33 of 630 | vaini
# port alfred
# Processing Record 34 of 630 | port alfred
# east london
# Processing Record 35 of 630 | east london
# broome
# Processing Record 36 of 630 | broome
# ixtapa
# Processing Record 37 of 630 | ixtapa
# mount isa
# Processing Record 38 of 630 | mount isa
# naze
# Processing Record 39 of 630 | naze
# rock sound
# Processing Record 40 of 630 | rock sound
# katsuura
# Processing Record 41 of 630 | katsuura
# coquimbo
# Processing Record 42 of 630 | coquimbo
# kalemie
# Processing Record 43 of 630 | kalemie
# tarakan
# Processing Record 44 of 630 | tarakan
# gaoual
# Processing Record 45 of 630 | gaoual
# clyde river
# Processing Record 46 of 630 | clyde river
# jamestown
# Processing Record 47 of 630 | jamestown
# biharamulo
# Processing Record 48 of 630 | biharamulo
# quatre cocos
# Processing Record 49 of 630 | quatre cocos
# belushya guba
# Processing Record 50 of 630 | belushya guba
# taolanaro
# Processing Record 51 of 630 | taolanaro
# vostok
# Processing Record 52 of 630 | vostok
# carnarvon
# Processing Record 53 of 630 | carnarvon
# cape town
# Processing Record 54 of 630 | cape town
# truth or consequences
# Processing Record 55 of 630 | truth or consequences
# zyryanka
# Processing Record 56 of 630 | zyryanka
# vao
# Processing Record 57 of 630 | vao
# lebu
# Processing Record 58 of 630 | lebu
# mar del plata
# Processing Record 59 of 630 | mar del plata
# puerto escondido
# Processing Record 60 of 630 | puerto escondido
# erenhot
# Processing Record 61 of 630 | erenhot
# kaitangata
# Processing Record 62 of 630 | kaitangata
# atuona
# Processing Record 63 of 630 | atuona
# sentyabrskiy
# Processing Record 64 of 630 | sentyabrskiy
# grand-santi
# Processing Record 65 of 630 | grand-santi
# mahebourg
# Processing Record 66 of 630 | mahebourg
# sawakin
# Processing Record 67 of 630 | sawakin
# mataura
# Processing Record 68 of 630 | mataura
# ust-kamchatsk
# Processing Record 69 of 630 | ust-kamchatsk
# torbay
# Processing Record 70 of 630 | torbay
# bambous virieux
# Processing Record 71 of 630 | bambous virieux
# ola
# Processing Record 72 of 630 | ola
# sangar
# Processing Record 73 of 630 | sangar
# ordu
# Processing Record 74 of 630 | ordu
# hobyo
# Processing Record 75 of 630 | hobyo
# castro
# Processing Record 76 of 630 | castro
# guozhen
# Processing Record 77 of 630 | guozhen
# jimenez
# Processing Record 78 of 630 | jimenez
# geraldton
# Processing Record 79 of 630 | geraldton
# kazalinsk
# Processing Record 80 of 630 | kazalinsk
# brainerd
# Processing Record 81 of 630 | brainerd
# butaritari
# Processing Record 82 of 630 | butaritari
# sheksna
# Processing Record 83 of 630 | sheksna
# asau
# Processing Record 84 of 630 | asau
# saint george
# Processing Record 85 of 630 | saint george
# longyearbyen
# Processing Record 86 of 630 | longyearbyen
# paradwip
# Processing Record 87 of 630 | paradwip
# crestview
# Processing Record 88 of 630 | crestview
# bredasdorp
# Processing Record 89 of 630 | bredasdorp
# providencia
# Processing Record 90 of 630 | providencia
# granard
# Processing Record 91 of 630 | granard
# talara
# Processing Record 92 of 630 | talara
# tuktoyaktuk
# Processing Record 93 of 630 | tuktoyaktuk
# saint anthony
# Processing Record 94 of 630 | saint anthony
# singaraja
# Processing Record 95 of 630 | singaraja
# kendari
# Processing Record 96 of 630 | kendari
# san patricio
# Processing Record 97 of 630 | san patricio
# ugoofaaru
# Processing Record 98 of 630 | ugoofaaru
# birin
# Processing Record 99 of 630 | birin
# kodiak
# Processing Record 100 of 630 | kodiak
# biak
# Processing Record 101 of 630 | biak
# thio
# Processing Record 102 of 630 | thio
# mackay
# Processing Record 103 of 630 | mackay
# kapaa
# Processing Record 104 of 630 | kapaa
# nizwa
# Processing Record 105 of 630 | nizwa
# upata
# Processing Record 106 of 630 | upata
# acarau
# Processing Record 107 of 630 | acarau
# korsakov
# Processing Record 108 of 630 | korsakov
# alofi
# Processing Record 109 of 630 | alofi
# tasiilaq
# Processing Record 110 of 630 | tasiilaq
# kavaratti
# Processing Record 111 of 630 | kavaratti
# impfondo
# Processing Record 112 of 630 | impfondo
# ostrovnoy
# Processing Record 113 of 630 | ostrovnoy
# meulaboh
# Processing Record 114 of 630 | meulaboh
# muzhi
# Processing Record 115 of 630 | muzhi
# waingapu
# Processing Record 116 of 630 | waingapu
# cuenca
# Processing Record 117 of 630 | cuenca
# nizhneudinsk
# Processing Record 118 of 630 | nizhneudinsk
# georgetown
# Processing Record 119 of 630 | georgetown
# bethel
# Processing Record 120 of 630 | bethel
# souillac
# Processing Record 121 of 630 | souillac
# nanortalik
# Processing Record 122 of 630 | nanortalik
# attawapiskat
# Processing Record 123 of 630 | attawapiskat
# upernavik
# Processing Record 124 of 630 | upernavik
# nizhneyansk
# Processing Record 125 of 630 | nizhneyansk
# norman wells
# Processing Record 126 of 630 | norman wells
# tsihombe
# Processing Record 127 of 630 | tsihombe
# kruisfontein
# Processing Record 128 of 630 | kruisfontein
# gorontalo
# Processing Record 129 of 630 | gorontalo
# ancud
# Processing Record 130 of 630 | ancud
# vila franca do campo
# Processing Record 131 of 630 | vila franca do campo
# bedele
# Processing Record 132 of 630 | bedele
# saleaula
# Processing Record 133 of 630 | saleaula
# boca do acre
# Processing Record 134 of 630 | boca do acre
# akcaabat
# Processing Record 135 of 630 | akcaabat
# fortuna
# Processing Record 136 of 630 | fortuna
# puerto ayora
# Processing Record 137 of 630 | puerto ayora
# half moon bay
# Processing Record 138 of 630 | half moon bay
# tiksi
# Processing Record 139 of 630 | tiksi
# haines junction
# Processing Record 140 of 630 | haines junction
# constitucion
# Processing Record 141 of 630 | constitucion
# cidreira
# Processing Record 142 of 630 | cidreira
# grand river south east
# Processing Record 143 of 630 | grand river south east
# chokurdakh
# Processing Record 144 of 630 | chokurdakh
# arlit
# Processing Record 145 of 630 | arlit
# chuy
# Processing Record 146 of 630 | chuy
# mogadishu
# Processing Record 147 of 630 | mogadishu
# solnechnyy
# Processing Record 148 of 630 | solnechnyy
# sur
# Processing Record 149 of 630 | sur
# revelstoke
# Processing Record 150 of 630 | revelstoke
# tukrah
# Processing Record 151 of 630 | tukrah
# mahaicony
# Processing Record 152 of 630 | mahaicony
# manokwari
# Processing Record 153 of 630 | manokwari
# hami
# Processing Record 154 of 630 | hami
# cherskiy
# Processing Record 155 of 630 | cherskiy
# boa vista
# Processing Record 156 of 630 | boa vista
# illoqqortoormiut
# Processing Record 157 of 630 | illoqqortoormiut
# allapalli
# Processing Record 158 of 630 | allapalli
# saskylakh
# Processing Record 159 of 630 | saskylakh
# evensk
# Processing Record 160 of 630 | evensk
# fort nelson
# Processing Record 161 of 630 | fort nelson
# coihaique
# Processing Record 162 of 630 | coihaique
# erzincan
# Processing Record 163 of 630 | erzincan
# concordia
# Processing Record 164 of 630 | concordia
# viytivka
# Processing Record 165 of 630 | viytivka
# saint-pierre
# Processing Record 166 of 630 | saint-pierre
# nan
# Processing Record 167 of 630 | nan
# chapais
# Processing Record 168 of 630 | chapais
# cordoba
# Processing Record 169 of 630 | cordoba
# shingu
# Processing Record 170 of 630 | shingu
# yulara
# Processing Record 171 of 630 | yulara
# atar
# Processing Record 172 of 630 | atar
# hasaki
# Processing Record 173 of 630 | hasaki
# busselton
# Processing Record 174 of 630 | busselton
# terrace bay
# Processing Record 175 of 630 | terrace bay
# nome
# Processing Record 176 of 630 | nome
# dikson
# Processing Record 177 of 630 | dikson
# esperance
# Processing Record 178 of 630 | esperance
# kushmurun
# Processing Record 179 of 630 | kushmurun
# samusu
# Processing Record 180 of 630 | samusu
# orlik
# Processing Record 181 of 630 | orlik
# bengkulu
# Processing Record 182 of 630 | bengkulu
# hermanus
# Processing Record 183 of 630 | hermanus
# zhezkazgan
# Processing Record 184 of 630 | zhezkazgan
# shenjiamen
# Processing Record 185 of 630 | shenjiamen
# tura
# Processing Record 186 of 630 | tura
# lagoa
# Processing Record 187 of 630 | lagoa
# mazabuka
# Processing Record 188 of 630 | mazabuka
# saint-philippe
# Processing Record 189 of 630 | saint-philippe
# pangnirtung
# Processing Record 190 of 630 | pangnirtung
# sassandra
# Processing Record 191 of 630 | sassandra
# hobart
# Processing Record 192 of 630 | hobart
# ijaki
# Processing Record 193 of 630 | ijaki
# rudbar
# Processing Record 194 of 630 | rudbar
# korla
# Processing Record 195 of 630 | korla
# los llanos de aridane
# Processing Record 196 of 630 | los llanos de aridane
# sao filipe
# Processing Record 197 of 630 | sao filipe
# avarua
# Processing Record 198 of 630 | avarua
# plettenberg bay
# Processing Record 199 of 630 | plettenberg bay
# alannay
# Processing Record 200 of 630 | alannay
# pimenta bueno
# Processing Record 201 of 630 | pimenta bueno
# barentsburg
# Processing Record 202 of 630 | barentsburg
# kaeo
# Processing Record 203 of 630 | kaeo
# champerico
# Processing Record 204 of 630 | champerico
# milledgeville
# Processing Record 205 of 630 | milledgeville
# asfi
# Processing Record 206 of 630 | asfi
# cattolica
# Processing Record 207 of 630 | cattolica
# new norfolk
# Processing Record 208 of 630 | new norfolk
# wahran
# Processing Record 209 of 630 | wahran
# dothan
# Processing Record 210 of 630 | dothan
# vila velha
# Processing Record 211 of 630 | vila velha
# atherton
# Processing Record 212 of 630 | atherton
# morristown
# Processing Record 213 of 630 | morristown
# thompson
# Processing Record 214 of 630 | thompson
# praia da vitoria
# Processing Record 215 of 630 | praia da vitoria
# arroio dos ratos
# Processing Record 216 of 630 | arroio dos ratos
# fairbanks
# Processing Record 217 of 630 | fairbanks
# grand gaube
# Processing Record 218 of 630 | grand gaube
# qianan
# Processing Record 219 of 630 | qianan
# khandyga
# Processing Record 220 of 630 | khandyga
# narsaq
# Processing Record 221 of 630 | narsaq
# hofn
# Processing Record 222 of 630 | hofn
# vaitupu
# Processing Record 223 of 630 | vaitupu
# arraial do cabo
# Processing Record 224 of 630 | arraial do cabo
# tual
# Processing Record 225 of 630 | tual
# salalah
# Processing Record 226 of 630 | salalah
# gurgan
# Processing Record 227 of 630 | gurgan
# abatskoye
# Processing Record 228 of 630 | abatskoye
# beloha
# Processing Record 229 of 630 | beloha
# toftir
# Processing Record 230 of 630 | toftir
# flin flon
# Processing Record 231 of 630 | flin flon
# keuruu
# Processing Record 232 of 630 | keuruu
# bulz
# Processing Record 233 of 630 | bulz
# concarneau
# Processing Record 234 of 630 | concarneau
# usinsk
# Processing Record 235 of 630 | usinsk
# campo grande
# Processing Record 236 of 630 | campo grande
# sitka
# Processing Record 237 of 630 | sitka
# berdigestyakh
# Processing Record 238 of 630 | berdigestyakh
# tripoli
# Processing Record 239 of 630 | tripoli
# khatanga
# Processing Record 240 of 630 | khatanga
# ndele
# Processing Record 241 of 630 | ndele
# destin
# Processing Record 242 of 630 | destin
# artyk
# Processing Record 243 of 630 | artyk
# ahtopol
# Processing Record 244 of 630 | ahtopol
# kamaishi
# Processing Record 245 of 630 | kamaishi
# najran
# Processing Record 246 of 630 | najran
# natuba
# Processing Record 247 of 630 | natuba
# puttur
# Processing Record 248 of 630 | puttur
# pierre
# Processing Record 249 of 630 | pierre
# klichka
# Processing Record 250 of 630 | klichka
# lata
# Processing Record 251 of 630 | lata
# lorengau
# Processing Record 252 of 630 | lorengau
# isoka
# Processing Record 253 of 630 | isoka
# hithadhoo
# Processing Record 254 of 630 | hithadhoo
# manta
# Processing Record 255 of 630 | manta
# lewistown
# Processing Record 256 of 630 | lewistown
# pevek
# Processing Record 257 of 630 | pevek
# ust-maya
# Processing Record 258 of 630 | ust-maya
# broken hill
# Processing Record 259 of 630 | broken hill
# gamba
# Processing Record 260 of 630 | gamba
# rocha
# Processing Record 261 of 630 | rocha
# tokur
# Processing Record 262 of 630 | tokur
# luau
# Processing Record 263 of 630 | luau
# santa vitoria
# Processing Record 264 of 630 | santa vitoria
# amderma
# Processing Record 265 of 630 | amderma
# santiago del estero
# Processing Record 266 of 630 | santiago del estero
# veseloyarsk
# Processing Record 267 of 630 | veseloyarsk
# ambagarh chauki
# Processing Record 268 of 630 | ambagarh chauki
# flinders
# Processing Record 269 of 630 | flinders
# huron
# Processing Record 270 of 630 | huron
# lasa
# Processing Record 271 of 630 | lasa
# floro
# Processing Record 272 of 630 | floro
# xining
# Processing Record 273 of 630 | xining
# dodge city
# Processing Record 274 of 630 | dodge city
# porbandar
# Processing Record 275 of 630 | porbandar
# camacha
# Processing Record 276 of 630 | camacha
# taltal
# Processing Record 277 of 630 | taltal
# samatau
# Processing Record 278 of 630 | samatau
# mgandu
# Processing Record 279 of 630 | mgandu
# subang
# Processing Record 280 of 630 | subang
# severo-kurilsk
# Processing Record 281 of 630 | severo-kurilsk
# komsomolskiy
# Processing Record 282 of 630 | komsomolskiy
# leningradskiy
# Processing Record 283 of 630 | leningradskiy
# avera
# Processing Record 284 of 630 | avera
# matagami
# Processing Record 285 of 630 | matagami
# takoradi
# Processing Record 286 of 630 | takoradi
# bilibino
# Processing Record 287 of 630 | bilibino
# pampas
# Processing Record 288 of 630 | pampas
# guerrero negro
# Processing Record 289 of 630 | guerrero negro
# morant bay
# Processing Record 290 of 630 | morant bay
# santa maria
# Processing Record 291 of 630 | santa maria
# rock springs
# Processing Record 292 of 630 | rock springs
# poli
# Processing Record 293 of 630 | poli
# oyem
# Processing Record 294 of 630 | oyem
# nagato
# Processing Record 295 of 630 | nagato
# xam nua
# Processing Record 296 of 630 | xam nua
# zhigansk
# Processing Record 297 of 630 | zhigansk
# coyuca
# Processing Record 298 of 630 | coyuca
# port hardy
# Processing Record 299 of 630 | port hardy
# hazorasp
# Processing Record 300 of 630 | hazorasp
# amapa
# Processing Record 301 of 630 | amapa
# yabrud
# Processing Record 302 of 630 | yabrud
# ambovombe
# Processing Record 303 of 630 | ambovombe
# benjamin aceval
# Processing Record 304 of 630 | benjamin aceval
# tynda
# Processing Record 305 of 630 | tynda
# oranjemund
# Processing Record 306 of 630 | oranjemund
# mayna
# Processing Record 307 of 630 | mayna
# djougou
# Processing Record 308 of 630 | djougou
# leninskoye
# Processing Record 309 of 630 | leninskoye
# mullaitivu
# Processing Record 310 of 630 | mullaitivu
# klaksvik
# Processing Record 311 of 630 | klaksvik
# lucea
# Processing Record 312 of 630 | lucea
# namibe
# Processing Record 313 of 630 | namibe
# garissa
# Processing Record 314 of 630 | garissa
# price
# Processing Record 315 of 630 | price
# chagda
# Processing Record 316 of 630 | chagda
# lekoni
# Processing Record 317 of 630 | lekoni
# bara
# Processing Record 318 of 630 | bara
# abancay
# Processing Record 319 of 630 | abancay
# te anau
# Processing Record 320 of 630 | te anau
# havre-saint-pierre
# Processing Record 321 of 630 | havre-saint-pierre
# port-cartier
# Processing Record 322 of 630 | port-cartier
# zhigalovo
# Processing Record 323 of 630 | zhigalovo
# kars
# Processing Record 324 of 630 | kars
# tumannyy
# Processing Record 325 of 630 | tumannyy
# ganta
# Processing Record 326 of 630 | ganta
# ponca city
# Processing Record 327 of 630 | ponca city
# berbera
# Processing Record 328 of 630 | berbera
# san policarpo
# Processing Record 329 of 630 | san policarpo
# severobaykalsk
# Processing Record 330 of 630 | severobaykalsk
# barra patuca
# Processing Record 331 of 630 | barra patuca
# grindavik
# Processing Record 332 of 630 | grindavik
# linxia
# Processing Record 333 of 630 | linxia
# vitim
# Processing Record 334 of 630 | vitim
# burnie
# Processing Record 335 of 630 | burnie
# campo maior
# Processing Record 336 of 630 | campo maior
# atka
# Processing Record 337 of 630 | atka
# izumo
# Processing Record 338 of 630 | izumo
# balaipungut
# Processing Record 339 of 630 | balaipungut
# caravelas
# Processing Record 340 of 630 | caravelas
# hirado
# Processing Record 341 of 630 | hirado
# olinda
# Processing Record 342 of 630 | olinda
# lompoc
# Processing Record 343 of 630 | lompoc
# bulaevo
# Processing Record 344 of 630 | bulaevo
# tuatapere
# Processing Record 345 of 630 | tuatapere
# airai
# Processing Record 346 of 630 | airai
# merrill
# Processing Record 347 of 630 | merrill
# beira
# Processing Record 348 of 630 | beira
# jumla
# Processing Record 349 of 630 | jumla
# patnos
# Processing Record 350 of 630 | patnos
# raudeberg
# Processing Record 351 of 630 | raudeberg
# roblin
# Processing Record 352 of 630 | roblin
# mount gambier
# Processing Record 353 of 630 | mount gambier
# abu samrah
# Processing Record 354 of 630 | abu samrah
# dianopolis
# Processing Record 355 of 630 | dianopolis
# omsukchan
# Processing Record 356 of 630 | omsukchan
# prince albert
# Processing Record 357 of 630 | prince albert
# paucartambo
# Processing Record 358 of 630 | paucartambo
# pokhara
# Processing Record 359 of 630 | pokhara
# ketchikan
# Processing Record 360 of 630 | ketchikan
# bandarbeyla
# Processing Record 361 of 630 | bandarbeyla
# faya
# Processing Record 362 of 630 | faya
# victoria
# Processing Record 363 of 630 | victoria
# owo
# Processing Record 364 of 630 | owo
# warwick
# Processing Record 365 of 630 | warwick
# khani
# Processing Record 366 of 630 | khani
# henties bay
# Processing Record 367 of 630 | henties bay
# pochutla
# Processing Record 368 of 630 | pochutla
# stara synyava
# Processing Record 369 of 630 | stara synyava
# dumai
# Processing Record 370 of 630 | dumai
# griffith
# Processing Record 371 of 630 | griffith
# deniliquin
# Processing Record 372 of 630 | deniliquin
# marcona
# Processing Record 373 of 630 | marcona
# verkhnevilyuysk
# Processing Record 374 of 630 | verkhnevilyuysk
# zhovtneve
# Processing Record 375 of 630 | zhovtneve
# isangel
# Processing Record 376 of 630 | isangel
# zainsk
# Processing Record 377 of 630 | zainsk
# conceicao do araguaia
# Processing Record 378 of 630 | conceicao do araguaia
# ames
# Processing Record 379 of 630 | ames
# bahia blanca
# Processing Record 380 of 630 | bahia blanca
# berlevag
# Processing Record 381 of 630 | berlevag
# empalme
# Processing Record 382 of 630 | empalme
# itoman
# Processing Record 383 of 630 | itoman
# dali
# Processing Record 384 of 630 | dali
# lumeje
# Processing Record 385 of 630 | lumeje
# deputatskiy
# Processing Record 386 of 630 | deputatskiy
# mizpe ramon
# Processing Record 387 of 630 | mizpe ramon
# krapivinskiy
# Processing Record 388 of 630 | krapivinskiy
# kudahuvadhoo
# Processing Record 389 of 630 | kudahuvadhoo
# hoquiam
# Processing Record 390 of 630 | hoquiam
# sri aman
# Processing Record 391 of 630 | sri aman
# kulhudhuffushi
# Processing Record 392 of 630 | kulhudhuffushi
# makaleng
# Processing Record 393 of 630 | makaleng
# southbridge
# Processing Record 394 of 630 | southbridge
# inhambane
# Processing Record 395 of 630 | inhambane
# egvekinot
# Processing Record 396 of 630 | egvekinot
# nishihara
# Processing Record 397 of 630 | nishihara
# bayangol
# Processing Record 398 of 630 | bayangol
# temba
# Processing Record 399 of 630 | temba
# dingle
# Processing Record 400 of 630 | dingle
# porto novo
# Processing Record 401 of 630 | porto novo
# mambolo
# Processing Record 402 of 630 | mambolo
# ninghai
# Processing Record 403 of 630 | ninghai
# adrar
# Processing Record 404 of 630 | adrar
# kitahiroshima
# Processing Record 405 of 630 | kitahiroshima
# port elizabeth
# Processing Record 406 of 630 | port elizabeth
# saldanha
# Processing Record 407 of 630 | saldanha
# lake charles
# Processing Record 408 of 630 | lake charles
# collie
# Processing Record 409 of 630 | collie
# vardo
# Processing Record 410 of 630 | vardo
# maragogi
# Processing Record 411 of 630 | maragogi
# chifeng
# Processing Record 412 of 630 | chifeng
# rawson
# Processing Record 413 of 630 | rawson
# sioux lookout
# Processing Record 414 of 630 | sioux lookout
# nemuro
# Processing Record 415 of 630 | nemuro
# aklavik
# Processing Record 416 of 630 | aklavik
# beringovskiy
# Processing Record 417 of 630 | beringovskiy
# talcahuano
# Processing Record 418 of 630 | talcahuano
# whitecourt
# Processing Record 419 of 630 | whitecourt
# milkovo
# Processing Record 420 of 630 | milkovo
# hamilton
# Processing Record 421 of 630 | hamilton
# yarada
# Processing Record 422 of 630 | yarada
# yarmouth
# Processing Record 423 of 630 | yarmouth
# ormara
# Processing Record 424 of 630 | ormara
# thinadhoo
# Processing Record 425 of 630 | thinadhoo
# urumqi
# Processing Record 426 of 630 | urumqi
# wamba
# Processing Record 427 of 630 | wamba
# lanzhou
# Processing Record 428 of 630 | lanzhou
# marquette
# Processing Record 429 of 630 | marquette
# sivaki
# Processing Record 430 of 630 | sivaki
# dongsheng
# Processing Record 431 of 630 | dongsheng
# bayir
# Processing Record 432 of 630 | bayir
# roald
# Processing Record 433 of 630 | roald
# sobolevo
# Processing Record 434 of 630 | sobolevo
# zagora
# Processing Record 435 of 630 | zagora
# naantali
# Processing Record 436 of 630 | naantali
# laguna
# Processing Record 437 of 630 | laguna
# plastun
# Processing Record 438 of 630 | plastun
# lethem
# Processing Record 439 of 630 | lethem
# merauke
# Processing Record 440 of 630 | merauke
# poum
# Processing Record 441 of 630 | poum
# karkaralinsk
# Processing Record 442 of 630 | karkaralinsk
# khasan
# Processing Record 443 of 630 | khasan
# saint-paul
# Processing Record 444 of 630 | saint-paul
# bronnoysund
# Processing Record 445 of 630 | bronnoysund
# duki
# Processing Record 446 of 630 | duki
# riyadh
# Processing Record 447 of 630 | riyadh
# mehamn
# Processing Record 448 of 630 | mehamn
# faro
# Processing Record 449 of 630 | faro
# xichang
# Processing Record 450 of 630 | xichang
# uacon
# Processing Record 451 of 630 | uacon
# karratha
# Processing Record 452 of 630 | karratha
# rawannawi
# Processing Record 453 of 630 | rawannawi
# dehloran
# Processing Record 454 of 630 | dehloran
# jaromerice nad rokytnou
# Processing Record 455 of 630 | jaromerice nad rokytnou
# skiros
# Processing Record 456 of 630 | skiros
# yar-sale
# Processing Record 457 of 630 | yar-sale
# kawalu
# Processing Record 458 of 630 | kawalu
# borazjan
# Processing Record 459 of 630 | borazjan
# banjar
# Processing Record 460 of 630 | banjar
# pueblo
# Processing Record 461 of 630 | pueblo
# tessalit
# Processing Record 462 of 630 | tessalit
# mango
# Processing Record 463 of 630 | mango
# sanchez
# Processing Record 464 of 630 | sanchez
# veraval
# Processing Record 465 of 630 | veraval
# sao felix do xingu
# Processing Record 466 of 630 | sao felix do xingu
# mocuba
# Processing Record 467 of 630 | mocuba
# iwanai
# Processing Record 468 of 630 | iwanai
# kurchum
# Processing Record 469 of 630 | kurchum
# acuna
# Processing Record 470 of 630 | acuna
# luanda
# Processing Record 471 of 630 | luanda
# kieta
# Processing Record 472 of 630 | kieta
# bathsheba
# Processing Record 473 of 630 | bathsheba
# grand-lahou
# Processing Record 474 of 630 | grand-lahou
# makakilo city
# Processing Record 475 of 630 | makakilo city
# sahbuz
# Processing Record 476 of 630 | sahbuz
# pleszew
# Processing Record 477 of 630 | pleszew
# sorland
# Processing Record 478 of 630 | sorland
# cockburn town
# Processing Record 479 of 630 | cockburn town
# batemans bay
# Processing Record 480 of 630 | batemans bay
# ponta do sol
# Processing Record 481 of 630 | ponta do sol
# skelleftea
# Processing Record 482 of 630 | skelleftea
# volodarskiy
# Processing Record 483 of 630 | volodarskiy
# black river
# Processing Record 484 of 630 | black river
# northam
# Processing Record 485 of 630 | northam
# hovd
# Processing Record 486 of 630 | hovd
# charters towers
# Processing Record 487 of 630 | charters towers
# dossor
# Processing Record 488 of 630 | dossor
# herrenberg
# Processing Record 489 of 630 | herrenberg
# iqaluit
# Processing Record 490 of 630 | iqaluit
# palmer
# Processing Record 491 of 630 | palmer
# saint-joseph
# Processing Record 492 of 630 | saint-joseph
# syamzha
# Processing Record 493 of 630 | syamzha
# samarai
# Processing Record 494 of 630 | samarai
# suwannaphum
# Processing Record 495 of 630 | suwannaphum
# kosjeric
# Processing Record 496 of 630 | kosjeric
# asayita
# Processing Record 497 of 630 | asayita
# port hedland
# Processing Record 498 of 630 | port hedland
# diego de almagro
# Processing Record 499 of 630 | diego de almagro
# denpasar
# Processing Record 500 of 630 | denpasar
# scarborough
# Processing Record 501 of 630 | scarborough
# buala
# Processing Record 502 of 630 | buala
# alugan
# Processing Record 503 of 630 | alugan
# lagoa vermelha
# Processing Record 504 of 630 | lagoa vermelha
# halalo
# Processing Record 505 of 630 | halalo
# la libertad
# Processing Record 506 of 630 | la libertad
# bambanglipuro
# Processing Record 507 of 630 | bambanglipuro
# annau
# Processing Record 508 of 630 | annau
# praya
# Processing Record 509 of 630 | praya
# hirara
# Processing Record 510 of 630 | hirara
# touros
# Processing Record 511 of 630 | touros
# pailon
# Processing Record 512 of 630 | pailon
# yaan
# Processing Record 513 of 630 | yaan
# buqayq
# Processing Record 514 of 630 | buqayq
# chara
# Processing Record 515 of 630 | chara
# telde
# Processing Record 516 of 630 | telde
# moussoro
# Processing Record 517 of 630 | moussoro
# opotiki
# Processing Record 518 of 630 | opotiki
# vagur
# Processing Record 519 of 630 | vagur
# koumac
# Processing Record 520 of 630 | koumac
# kununurra
# Processing Record 521 of 630 | kununurra
# la presa
# Processing Record 522 of 630 | la presa
# faanui
# Processing Record 523 of 630 | faanui
# swan hill
# Processing Record 524 of 630 | swan hill
# uwayl
# Processing Record 525 of 630 | uwayl
# maniitsoq
# Processing Record 526 of 630 | maniitsoq
# umm lajj
# Processing Record 527 of 630 | umm lajj
# meadow lake
# Processing Record 528 of 630 | meadow lake
# trairi
# Processing Record 529 of 630 | trairi
# lae
# Processing Record 530 of 630 | lae
# tandil
# Processing Record 531 of 630 | tandil
# makokou
# Processing Record 532 of 630 | makokou
# tilichiki
# Processing Record 533 of 630 | tilichiki
# mama
# Processing Record 534 of 630 | mama
# sataua
# Processing Record 535 of 630 | sataua
# kabompo
# Processing Record 536 of 630 | kabompo
# luderitz
# Processing Record 537 of 630 | luderitz
# novikovo
# Processing Record 538 of 630 | novikovo
# vilhena
# Processing Record 539 of 630 | vilhena
# talnakh
# Processing Record 540 of 630 | talnakh
# lewiston
# Processing Record 541 of 630 | lewiston
# kuche
# Processing Record 542 of 630 | kuche
# carutapera
# Processing Record 543 of 630 | carutapera
# lalmohan
# Processing Record 544 of 630 | lalmohan
# sayyan
# Processing Record 545 of 630 | sayyan
# lubbock
# Processing Record 546 of 630 | lubbock
# taos
# Processing Record 547 of 630 | taos
# srednekolymsk
# Processing Record 548 of 630 | srednekolymsk
# yuanping
# Processing Record 549 of 630 | yuanping
# russell
# Processing Record 550 of 630 | russell
# kathu
# Processing Record 551 of 630 | kathu
# portland
# Processing Record 552 of 630 | portland
# kilindoni
# Processing Record 553 of 630 | kilindoni
# keelung
# Processing Record 554 of 630 | keelung
# tautira
# Processing Record 555 of 630 | tautira
# sedam
# Processing Record 556 of 630 | sedam
# kysyl-syr
# Processing Record 557 of 630 | kysyl-syr
# lahaina
# Processing Record 558 of 630 | lahaina
# okakarara
# Processing Record 559 of 630 | okakarara
# erzin
# Processing Record 560 of 630 | erzin
# dudinka
# Processing Record 561 of 630 | dudinka
# wanning
# Processing Record 562 of 630 | wanning
# oostburg
# Processing Record 563 of 630 | oostburg
# santa rosa
# Processing Record 564 of 630 | santa rosa
# savinka
# Processing Record 565 of 630 | savinka
# shelburne
# Processing Record 566 of 630 | shelburne
# dryden
# Processing Record 567 of 630 | dryden
# chabahar
# Processing Record 568 of 630 | chabahar
# caceres
# Processing Record 569 of 630 | caceres
# badou
# Processing Record 570 of 630 | badou
# masalli
# Processing Record 571 of 630 | masalli
# jefferson city
# Processing Record 572 of 630 | jefferson city
# colares
# Processing Record 573 of 630 | colares
# prince rupert
# Processing Record 574 of 630 | prince rupert
# el cocuy
# Processing Record 575 of 630 | el cocuy
# shenkursk
# Processing Record 576 of 630 | shenkursk
# ngukurr
# Processing Record 577 of 630 | ngukurr
# kahului
# Processing Record 578 of 630 | kahului
# marawi
# Processing Record 579 of 630 | marawi
# amazar
# Processing Record 580 of 630 | amazar
# bend
# Processing Record 581 of 630 | bend
# oistins
# Processing Record 582 of 630 | oistins
# katangli
# Processing Record 583 of 630 | katangli
# ludwigslust
# Processing Record 584 of 630 | ludwigslust
# kyren
# Processing Record 585 of 630 | kyren
# rincon
# Processing Record 586 of 630 | rincon
# port lincoln
# Processing Record 587 of 630 | port lincoln
# the valley
# Processing Record 588 of 630 | the valley
# ahipara
# Processing Record 589 of 630 | ahipara
# tawkar
# Processing Record 590 of 630 | tawkar
# mount darwin
# Processing Record 591 of 630 | mount darwin
# baft
# Processing Record 592 of 630 | baft
# umzimvubu
# Processing Record 593 of 630 | umzimvubu
# porto santo
# Processing Record 594 of 630 | porto santo
# saint-georges
# Processing Record 595 of 630 | saint-georges
# axim
# Processing Record 596 of 630 | axim
# bodden town
# Processing Record 597 of 630 | bodden town
# yatou
# Processing Record 598 of 630 | yatou
# pitsunda
# Processing Record 599 of 630 | pitsunda
# ekhabi
# Processing Record 600 of 630 | ekhabi
# tosya
# Processing Record 601 of 630 | tosya
# chokwe
# Processing Record 602 of 630 | chokwe
# rawlins
# Processing Record 603 of 630 | rawlins
# kloulklubed
# Processing Record 604 of 630 | kloulklubed
# goderich
# Processing Record 605 of 630 | goderich
# talakan
# Processing Record 606 of 630 | talakan
# krasnoselkup
# Processing Record 607 of 630 | krasnoselkup
# roebourne
# Processing Record 608 of 630 | roebourne
# cherlak
# Processing Record 609 of 630 | cherlak
# houston
# Processing Record 610 of 630 | houston
# ureki
# Processing Record 611 of 630 | ureki
# novyy urengoy
# Processing Record 612 of 630 | novyy urengoy
# sola
# Processing Record 613 of 630 | sola
# yinchuan
# Processing Record 614 of 630 | yinchuan
# mercedes
# Processing Record 615 of 630 | mercedes
# safford
# Processing Record 616 of 630 | safford
# wulanhaote
# Processing Record 617 of 630 | wulanhaote
# nerchinsk
# Processing Record 618 of 630 | nerchinsk
# dunedin
# Processing Record 619 of 630 | dunedin
# sabang
# Processing Record 620 of 630 | sabang
# manturovo
# Processing Record 621 of 630 | manturovo
# khalimbekaul
# Processing Record 622 of 630 | khalimbekaul
# pafos
# Processing Record 623 of 630 | pafos
# lesnikovo
# Processing Record 624 of 630 | lesnikovo
# vaitape
# Processing Record 625 of 630 | vaitape
# shchuchye
# Processing Record 626 of 630 | shchuchye
# hambantota
# Processing Record 627 of 630 | hambantota
# kibakwe
# Processing Record 628 of 630 | kibakwe
# san lorenzo
# Processing Record 629 of 630 | san lorenzo
# ahuimanu
# Processing Record 630 of 630 | ahuimanu

# %%
weather_df.to_csv(output_data_file, index=False)
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-a749a16b4c95> in <module>
# ----> 1 weather_df.to_csv(output_data_file, index=False)
#       2 weather_df.head()
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: './cities.csv'

# %%
#No cities with humidity >100
rm_hum_df = weather_df.loc[(weather_df['Humidity']>100)]
len(rm_hum_df)

# %%
#Clean city data
clean_city_data = weather_df
clean_city_data.head()

# %%
#Lat vs. Temp plot
latitude = clean_city_data['Lat']
max_temp = clean_city_data['Max Temp']

plt.scatter(latitude, max_temp)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature F')
plt.title(f"City Latitude vs. Max Temperature F {datetime.datetime.now().strftime('%m/%d/%y')}")
plt.show()
print("Analyzing the relationship between the latitude and maximum temperature of various cities")

# %%
#Lat vs. Humidity plot
latitude = clean_city_data['Lat']
humidity = clean_city_data['Humidity']

plt.scatter(latitude, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title(f"City Latitude vs. Humidity % {datetime.datetime.now().strftime('%m/%d/%y')}")
plt.show()

print("Analyzing the relationship between the latitude and humidity of various cities")

# %%
#Lat vs. Cloudiness plot
latitude = clean_city_data['Lat']
cloudiness = clean_city_data['Cloudiness']

plt.scatter(latitude, cloudiness)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs. Cloudiness {datetime.datetime.now().strftime('%m/%d/%y')}")
plt.show()

print("Analyzing the relationship between the latitude and cloudiness of various cities")

# %%
#Lat vs. Wind Speed
latitude = clean_city_data['Lat']
wind_speed = clean_city_data['Wind Speed']

plt.scatter(latitude, wind_speed)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed mph')
plt.title(f"City Latitude vs. Wind Speed mph {datetime.datetime.now().strftime('%m/%d/%y')}")
plt.show()
print("Analyzing the relationship between the latitude and wind speed of various cities")

# %%
#Linear Regression
#Northern Hemisphere Lat vs. Max Temp
nh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']>0)]

nh_latitude = nh_clean_city_data['Lat']
max_temp = nh_clean_city_data['Max Temp']

plt.scatter(nh_latitude, max_temp)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature F')
plt.title(f"Northern Hemisphere Latitude vs. Max Temperature F {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, max_temp)
regress_values = nh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(nh_latitude, regress_values,"r-")
plt.annotate(line_eq,(5,40),fontsize=15, color='red')
plt.show()

print("Analyzing the relationship between the latitude and max temperature of various cities in the northern hemisphere.")
print("The results indicate that the correlation between proximity to the equator and max temperature is moderately strong in the northern hemisphere.")

# %%
#Linear Regression
#Southern Hemisphere Lat vs. Max Temp
sh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']<0)]

sh_latitude = sh_clean_city_data['Lat']
max_temp = sh_clean_city_data['Max Temp']

plt.scatter(sh_latitude, max_temp)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature F')
plt.title(f"Southern Hemisphere Latitude vs. Max Temperature F {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, max_temp)
regress_values = sh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(sh_latitude, regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15, color='red')
plt.show()

print("Analyzing the relationship between the latitude and max temperature of various cities in the southern hemisphere.")
print("The results indicate that the correlation between proximity to the equator and max temperature is moderately strong in the southern hemisphere.")

# %%
#Linear Regression
#Nothern Hemisphere Lat vs. Humidity
nh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']>0)]

nh_latitude = nh_clean_city_data['Lat']
humidity = nh_clean_city_data['Humidity']

plt.scatter(nh_latitude, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Northern Hemisphere Latitude vs. Humidity {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, humidity)
regress_values = nh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(nh_latitude, regress_values,"r-")
plt.annotate(line_eq,(0,35),fontsize=12, color='red')
plt.show()
print("Analyzing the relationship between the latitude and humidity of various cities in the northern hemisphere.")
print("The results indicate no correlation between latitude and humidity in the northern hemisphere.")

# %%
#Linear Regression
#Southern Hemisphere Lat vs. Humidity
sh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']<0)]

sh_latitude = sh_clean_city_data['Lat']
humidity = sh_clean_city_data['Humidity']

plt.scatter(sh_latitude, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Southern Hemisphere Latitude vs. Humidity {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, humidity)
regress_values = sh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(sh_latitude, regress_values,"r-")
plt.annotate(line_eq,(-50,35),fontsize=12, color='red')
plt.show()

print("Analyzing the relationship between the latitude and humidity of various cities in the southern hemisphere.")
print("The results indicate a very weak correlation between latitude and humidity in the southern hemisphere.")

# %%
#Linear Regression
#Northern Hemisphere Lat vs. Cloudiness
nh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']>0)]

nh_latitude = nh_clean_city_data['Lat']
cloudiness = nh_clean_city_data['Cloudiness']

plt.scatter(nh_latitude, cloudiness)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Northern Hemisphere Latitude vs. Cloudiness {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, cloudiness)
regress_values = nh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(nh_latitude, regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=12, color='red')
plt.show()
print("Analyzing the relationship between the latitude and cloudiness of various cities in the northern hemisphere.")
print("No correlation between latitude and cloudiness in the northern hemisphere.")

# %%
#Linear Regression
#Southern Hemisphere Lat vs. Cloudiness
sh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']<0)]

sh_latitude = sh_clean_city_data['Lat']
cloudiness = sh_clean_city_data['Cloudiness']

plt.scatter(sh_latitude, cloudiness)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Southern Hemisphere Latitude vs. Cloudiness {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, cloudiness)
regress_values = sh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(sh_latitude, regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=12, color='red')
plt.show()

print("Analyzing the relationship between the latitude and cloudiness of various cities in the southern hemisphere.")
print("The results indicate a weak correlation between latitude and cloudiness in the southern hemisphere")

# %%
#Linear Regression
#Nothern Hemisphere Lat vs. Wind Speed
nh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']>0)]

nh_latitude = nh_clean_city_data['Lat']
wind_speed = nh_clean_city_data['Wind Speed']

plt.scatter(nh_latitude, wind_speed)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Northern Hemisphere Latitude vs. Wind Speed {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_latitude, wind_speed)
regress_values = nh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(nh_latitude, regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=12, color='red')
plt.show()

print("Analyzing the relationship between the latitude and wind speed of various cities in the northern hemisphere.")
print("The results indicate no correlation between latitude and wind speed in the northern hemisphere.")

# %%
#Linear Regression
#Southern Hemisphere Lat vs. Wind Speed
sh_clean_city_data = clean_city_data.loc[(clean_city_data['Lat']<0)]

sh_latitude = sh_clean_city_data['Lat']
wind_speed = sh_clean_city_data['Wind Speed']

plt.scatter(sh_latitude, wind_speed)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Southern Hemisphere Latitude vs. Wind Speed {datetime.datetime.now().strftime('%m/%d/%y')}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_latitude, wind_speed)
regress_values = sh_latitude * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.plot(sh_latitude, regress_values,"r-")
plt.annotate(line_eq,(-55,5),fontsize=12, color='red')
plt.show()

print("Analyzing the relationship between the latitude and wind speed of various cities in the southern hemisphere.")
print("The results indicate a very weak correlation between latitude and wind speed in the southern hemisphere.")
